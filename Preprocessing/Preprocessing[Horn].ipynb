# %% [markdown]
# <a href="https://colab.research.google.com/github/xychong/edgeaimonitoring/blob/main/Preprocessing/Preprocessing%5BHorn%5D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import librosa, librosa.display
import numpy as np
import os

# %%
pathname = "/content/drive/MyDrive/FYP Data/Horn"

# %%
# Display all filenames
sum = 0
for filename in os.listdir(pathname):
  sum += 1
  print(filename)
# Out:
# 24074-1-0-3.wav
# 24074-1-0-1.wav
# 24074-1-0-11.wav
# 24074-1-0-13.wav
# 24074-1-0-10.wav
# 24074-1-0-0.wav
# 24074-1-0-12.wav
# 24074-1-0-2.wav
# 24074-1-0-6.wav
# 24074-1-0-4.wav
# 24074-1-0-9.wav
# 24074-1-0-8.wav
# 24074-1-0-5.wav
# 24074-1-0-7.wav
# 28808-1-0-7.wav
# 28808-1-0-4.wav
# 28808-1-0-8.wav
# 28808-1-0-11.wav
# 28808-1-0-2.wav
# 28808-1-0-1.wav
# 28808-1-1-1.wav
# 28808-1-0-0.wav
# 28808-1-1-0.wav
# 28808-1-0-5.wav
# 28808-1-0-3.wav
# 28808-1-0-6.wav
# 28808-1-0-9.wav
# 28808-1-0-10.wav
# 72567-1-1-0.wav
# 72567-1-0-1.wav
# 72567-1-2-4.wav
# 72567-1-2-1.wav
# 72567-1-2-2.wav
# 72567-1-0-0.wav
# 72567-1-3-0.wav
# 72567-1-2-0.wav
# 72567-1-2-5.wav
# 72567-1-2-3.wav
# 72567-1-4-3.wav
# 72567-1-5-0.wav
# 72567-1-4-5.wav
# 72567-1-4-0.wav
# 72567-1-4-7.wav
# 72567-1-4-6.wav
# 72567-1-4-2.wav
# 72567-1-4-1.wav
# 72567-1-4-4.wav
# 199769-1-0-1.wav
# 199769-1-0-0.wav
# 199769-1-0-10.wav
# 199769-1-0-2.wav
# 199769-1-0-12.wav
# 199769-1-0-15.wav
# 199769-1-0-11.wav
# ...

# %%
# Check that all files are included
print (sum)
# Out:
# 205

# %%
n_fft = 2048
hop_length = 512
for filename in os.listdir(pathname):
  x,sr = librosa.load(pathname + "/" + filename, sr = 44100)  # load audio file with sampling rate 44.1k Hz
  stft = librosa.stft(x, n_fft = n_fft, hop_length = hop_length)
  amplitudeindB = librosa.amplitude_to_db(np.abs(stft), ref=np.max)
  print (np.max(abs(amplitudeindB))) # gives us max dB value of audio for each audio file
# Out:
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# ...

# %% [markdown]
# This means that maximum audio level is at 80dB for all audio files in "Horn" dataset.

# %%
def displayTime(startFrame, endFrame):    
    print(' start time: ' + str(startFrame/sr) + ', end time: ' + str(endFrame/sr))

# %%
# Obtain non-silent intervals within each track
# Allows me to have a better idea of how to trim each track into the desired 4s duration
for filename in os.listdir(pathname):
  x,sr = librosa.load(pathname + "/" + filename, sr = 44100)
  nonmuteportions = librosa.effects.split(x) # default top_db = 60 dB
  for i in nonmuteportions:    
    print(filename)  
    displayTime(i[0],i[1])
# Out:
# 24074-1-0-3.wav
#  start time: 0.0, end time: 4.0
# 24074-1-0-1.wav
#  start time: 0.0, end time: 4.0
# 24074-1-0-11.wav
#  start time: 0.0, end time: 4.0
# 24074-1-0-13.wav
#  start time: 0.0, end time: 4.0
# 24074-1-0-10.wav
#  start time: 0.0, end time: 4.0
# 24074-1-0-0.wav
#  start time: 0.0, end time: 4.0
# 24074-1-0-12.wav
#  start time: 0.0, end time: 4.0
# 24074-1-0-2.wav
#  start time: 0.0, end time: 4.0
# 24074-1-0-6.wav
#  start time: 0.0, end time: 4.0
# 24074-1-0-4.wav
#  start time: 0.0, end time: 4.0
# 24074-1-0-9.wav
#  start time: 0.0, end time: 4.0
# 24074-1-0-8.wav
#  start time: 0.0, end time: 4.0
# 24074-1-0-5.wav
#  start time: 0.0, end time: 4.0
# 24074-1-0-7.wav
#  start time: 0.0, end time: 4.0
# 28808-1-0-7.wav
#  start time: 0.0, end time: 4.0
# 28808-1-0-4.wav
#  start time: 0.0, end time: 4.0
# 28808-1-0-8.wav
#  start time: 0.0, end time: 4.0
# 28808-1-0-11.wav
#  start time: 0.0, end time: 4.0
# 28808-1-0-2.wav
#  start time: 0.0, end time: 4.0
# ...

# %% [markdown]
# #### Trim audio tracks that are >4s into multiple tracks of 4s each

# %% [markdown]
# By looking at data above, there are only 4 audio tracks >4s in length. Hence, I can just trim these 4 tracks manually into multiple segments of 4s, by observing which part of the audio track contains silence.

# %%
from pydub import AudioSegment

# %%
horn1 = AudioSegment.from_wav(pathname + "/" + "241114__unclesigmund__toy-car-horn.wav")

# %%
newfilename = "horn1trimmed"

horn1_1_4 = horn1[:4000]
horn1_1_4.export(pathname + "/" + newfilename + "1", format = "wav")

horn1_2_4 = horn1[4000:8000]
horn1_2_4.export(pathname + "/" + newfilename + "2", format = "wav")

# the last file being exported always have a delay
# adding this file to make sure all files I need are exported
# will manually delete this audio file generated 
horn1_empty_4 = horn1[8000:9000]
horn1_empty_4.export(pathname + "/" + newfilename + "empty", format = "wav")
# Out:
# <_io.BufferedRandom name='/content/drive/MyDrive/FYP Data/Horn/horn1trimmedempty'>

# %%
horn2 = AudioSegment.from_wav(pathname + "/" + "402958__inspectorj__car-alarm-horn-walking-past-a.wav")

# %%
newfilename = "horn2trimmed"

horn2_1_4 = horn2[23.2:4023.2]
horn2_1_4.export(pathname + "/" + newfilename + "1", format = "wav")

horn2_2_4 = horn2[4023.2:8023.2]
horn2_2_4.export(pathname + "/" + newfilename + "2", format = "wav")

horn2_3_4 = horn2[8023.2:12023.2]
horn2_3_4.export(pathname + "/" + newfilename + "3", format = "wav")

horn2_4_4 = horn2[12023.2:16023.2]
horn2_4_4.export(pathname + "/" + newfilename + "4", format = "wav")

horn2_5_4 = horn2[16023.2:20023.2]
horn2_5_4.export(pathname + "/" + newfilename + "5", format = "wav")

horn2_6_4 = horn2[20023.2:24023.2]
horn2_6_4.export(pathname + "/" + newfilename + "6", format = "wav")

horn2_empty_4 = horn2[8000:9000]
horn2_empty_4.export(pathname + "/" + newfilename + "empty", format = "wav")
# Out:
# <_io.BufferedRandom name='/content/drive/MyDrive/FYP Data/Horn/horn2trimmedempty'>

# %%
horn3 = AudioSegment.from_wav(pathname + "/" + "450821__kyles__truck-pickup-horn-honk-aggressive-annoyed-various1.wav")

# %%
newfilename = "horn3trimmed"

horn3_1_4 = horn3[:4000]
horn3_1_4.export(pathname + "/" + newfilename + "1", format = "wav")

horn3_2_4 = horn3[5000:9000]
horn3_2_4.export(pathname + "/" + newfilename + "2", format = "wav")

horn3_3_4 = horn3[12000:16000]
horn3_3_4.export(pathname + "/" + newfilename + "3", format = "wav")

horn3_4_4 = horn3[17000:21000]
horn3_4_4.export(pathname + "/" + newfilename + "4", format = "wav")

horn3_5_4 = horn3[22000:26000]
horn3_5_4.export(pathname + "/" + newfilename + "5", format = "wav")

horn3_empty_4 = horn3[26000:30000]
horn3_empty_4.export(pathname + "/" + newfilename + "empty", format = "wav")
# Out:
# <_io.BufferedRandom name='/content/drive/MyDrive/FYP Data/Horn/horn3trimmedempty'>

# %%
horn4 = AudioSegment.from_wav(pathname + "/" + "504564__dominikbraun__car-horn-blast-wav.wav")

# %%
newfilename = "horn4trimmed"

horn4_1_4 = horn4[1000:5000]
horn4_1_4.export(pathname + "/" + newfilename + "1", format = "wav")

horn4_2_4 = horn4[4800:8800]
horn4_2_4.export(pathname + "/" + newfilename + "2", format = "wav")

horn4_3_4 = horn4[10700:14700]
horn4_3_4.export(pathname + "/" + newfilename + "3", format = "wav")

horn4_4_4 = horn4[15300:19300]
horn4_4_4.export(pathname + "/" + newfilename + "4", format = "wav")

horn4_5_4 = horn4[21000:25000]
horn4_5_4.export(pathname + "/" + newfilename + "5", format = "wav")

horn4_6_4 = horn4[24000:28000]
horn4_6_4.export(pathname + "/" + newfilename + "6", format = "wav")

horn4_7_4 = horn4[26000:30000]
horn4_7_4.export(pathname + "/" + newfilename + "7", format = "wav")

horn4_empty_4 = horn4[30000:32000]
horn4_empty_4.export(pathname + "/" + newfilename + "empty", format = "wav")
# Out:
# <_io.BufferedRandom name='/content/drive/MyDrive/FYP Data/Horn/horn4trimmedempty'>

# %% [markdown]
# #### Pad audio data that are <4s in length with silences at the back

# %%
# Check duration of audio data <4s
for filename in os.listdir(pathname):
  audio = AudioSegment.from_file(pathname + "/" + filename)
  if audio.duration_seconds < 4: 
    print(filename)
    print(audio.duration_seconds)
# Out:
# 72567-1-1-0.wav
# 3.21
# 72567-1-3-0.wav
# 1.14
# 72567-1-5-0.wav
# 3.97
# 185436-1-0-0.wav
# 1.415625
# 185436-1-2-0.wav
# 2.5481041666666666
# 185436-1-3-0.wav
# 2.6896875
# 185436-1-4-0.wav
# 3.82
# 185436-1-6-0.wav
# 2.97
# 185436-1-7-0.wav
# 1.27
# 185436-1-5-0.wav
# 1.415625
# 46391-1-1-0.wav
# 1.09
# 72259-1-1-0.wav
# 3.77
# 71439-1-0-0.wav
# 1.38
# 72259-1-2-0.wav
# 3.23
# 72259-1-3-0.wav
# 3.95
# 72259-1-8-0.wav
# 3.95
# 99812-1-5-0.wav
# 2.53
# 99812-1-3-0.wav
# 2.14
# 99812-1-4-0.wav
# 3.5059863945578233
# 99812-1-6-0.wav
# 2.53
# 180156-1-6-0.wav
# 3.905104166666667
# 180156-1-0-0.wav
# 2.357125
# 180156-1-5-0.wav
# 1.6183333333333334
# 180156-1-1-0.wav
# 1.42
# 180156-1-10-0.wav
# 1.46
# 180156-1-4-0.wav
# 1.21
# 436588__julien-matthey__jm-transport-ext-horn-01b-car-2x-mini-countryman.wav
# 1.9592916666666667
# 563898__ebuzer__car-horn-eu2.wav
# 1.3318367346938775
# 349922__bigmanjoe__car-horn-honk.wav
# 3.200657596371882
# 517673__danlucaz__car-horn.wav
# ...

# %%
# Pad each audio with silences until their duration hit 4s
for filename in os.listdir(pathname):
  audio = AudioSegment.from_file(pathname + "/" + filename)
  if audio.duration_seconds < 4: 
    pad_ms = 4000 - (audio.duration_seconds * 1000) # milliseconds of silences needed
    silence = AudioSegment.silent(duration=pad_ms)
    padded = audio + silence
    print(filename)
    print(padded.duration_seconds)
# Out:
# 72567-1-1-0.wav
# 3.999875
# 72567-1-3-0.wav
# 3.999875
# 72567-1-5-0.wav
# 3.999875
# 185436-1-0-0.wav
# 3.9998541666666667
# 185436-1-2-0.wav
# 3.9998958333333334
# 185436-1-3-0.wav
# 3.9998958333333334
# 185436-1-4-0.wav
# 3.999875
# 185436-1-6-0.wav
# 3.9998541666666667
# 185436-1-7-0.wav
# 3.9998958333333334
# 185436-1-5-0.wav
# 3.9998541666666667
# 46391-1-1-0.wav
# 3.999863945578231
# 72259-1-1-0.wav
# 3.999863945578231
# 71439-1-0-0.wav
# 3.9998866213151927
# 72259-1-2-0.wav
# 3.999909297052154
# 72259-1-3-0.wav
# 3.999909297052154
# 72259-1-8-0.wav
# 3.999909297052154
# 99812-1-5-0.wav
# 3.999863945578231
# 99812-1-3-0.wav
# 3.9998866213151927
# 99812-1-4-0.wav
# 3.9998866213151927
# 99812-1-6-0.wav
# 3.999863945578231
# 180156-1-6-0.wav
# 3.9998958333333334
# 180156-1-0-0.wav
# 3.9998541666666667
# 180156-1-5-0.wav
# 3.999833333333333
# 180156-1-1-0.wav
# 3.999875
# 180156-1-10-0.wav
# 3.999875
# 180156-1-4-0.wav
# 3.9998541666666667
# ...

# %%
filecount = 0
for filename in os.listdir(pathname):
  audio = AudioSegment.from_file(pathname + "/" + filename)
  filecount += 1

print(filecount)
# Out:
# 221

# %%
# Export and replace the files
for filename in os.listdir(pathname):
  audio = AudioSegment.from_file(pathname + "/" + filename)
  if audio.duration_seconds < 4: 
    pad_ms = 4000 - (audio.duration_seconds * 1000) # milliseconds of silences needed
    silence = AudioSegment.silent(duration=pad_ms)
    padded = audio + silence
    padded.export(pathname + "/" + filename, format='wav')

# %%
filecount = 0
for filename in os.listdir(pathname):
  audio = AudioSegment.from_file(pathname + "/" + filename)
  filecount += 1

print(filecount)
# Out:
# 221

# %%
# Check if there are still audio files >4s
for filename in os.listdir(pathname):
  audio = AudioSegment.from_file(pathname + "/" + filename)
  if audio.duration_seconds > 4: 
    print(filename)
    print(audio.duration_seconds)
# Out:
# 182474__keweldog__car-horn.wav
# 4.322267573696145
# 54086__guitarguy1985__horn.wav
# 4.597551020408163

# %% [markdown]
# It turns out that I missed 2 audio tracks >4s in duration previously. Now, I have to trim these 2 audio tracks into multiple segments of 4s.

# %%
horn5 = AudioSegment.from_wav(pathname + "/" + "182474__keweldog__car-horn.wav")

# %%
newfilename = "horn5trimmed"

horn5_1_4 = horn5[150:4150]
horn5_1_4.export(pathname + "/" + newfilename + "1", format = "wav")

horn5_empty_4 = horn5[4000:4150]
horn5_empty_4.export(pathname + "/" + newfilename + "empty", format = "wav")
# Out:
# <_io.BufferedRandom name='/content/drive/MyDrive/FYP Data/Horn/horn5trimmedempty'>

# %%
horn6 = AudioSegment.from_wav(pathname + "/" + "54086__guitarguy1985__horn.wav")

# %%
newfilename = "horn6trimmed"

horn6_1_4 = horn6[:4000]
horn6_1_4.export(pathname + "/" + newfilename + "1", format = "wav")

horn6_empty_4 = horn6[4000:4150]
horn6_empty_4.export(pathname + "/" + newfilename + "empty", format = "wav")
# Out:
# <_io.BufferedRandom name='/content/drive/MyDrive/FYP Data/Horn/horn6trimmedempty'>

# %%
# Check if there are still audio files >4s
for filename in os.listdir(pathname):
  audio = AudioSegment.from_file(pathname + "/" + filename)
  if audio.duration_seconds > 4: 
    print(filename)
    print(audio.duration_seconds)

# %%
# Renaming every file within the dataset
category = "horn"
count = 1;
for filename in os.listdir(pathname):
  os.rename(pathname + "/" + filename, pathname + "/" + category + " " + str(count) + ".wav")
  count += 1

# %%
# Check duration of all audio files
for filename in os.listdir(pathname):
  audio = AudioSegment.from_file(pathname + "/" + filename)
  print(filename)
  print(audio.duration_seconds)
# Out:
# horn 1.wav
# 4.0
# horn 2.wav
# 4.0
# horn 3.wav
# 4.0
# horn 4.wav
# 4.0
# horn 5.wav
# 4.0
# horn 6.wav
# 4.0
# horn 7.wav
# 4.0
# horn 8.wav
# 4.0
# horn 9.wav
# 4.0
# horn 10.wav
# 4.0
# horn 11.wav
# 4.0
# horn 12.wav
# 4.0
# horn 13.wav
# 4.0
# horn 14.wav
# 4.0
# horn 15.wav
# 4.0
# horn 16.wav
# 4.0
# horn 17.wav
# 4.0
# horn 18.wav
# 4.0
# horn 19.wav
# 4.0
# horn 20.wav
# 4.0
# horn 21.wav
# 4.0
# horn 22.wav
# 4.0
# horn 23.wav
# 4.0
# horn 24.wav
# 4.0
# horn 25.wav
# 4.0
# horn 26.wav
# 4.0
# horn 27.wav
# 4.0
# horn 28.wav
# 4.0
# horn 29.wav
# 3.999875
# horn 30.wav
# 4.0
# horn 31.wav
# 4.0
# horn 32.wav
# 4.0
# horn 33.wav
# 4.0
# horn 34.wav
# 4.0
# horn 35.wav
# 3.999875
# horn 36.wav
# 4.0
# horn 37.wav
# 4.0
# horn 38.wav
# 4.0
# horn 39.wav
# 4.0
# horn 40.wav
# 3.999875
# horn 41.wav
# 4.0
# horn 42.wav
# 4.0
# horn 43.wav
# 4.0
# horn 44.wav
# 4.0
# horn 45.wav
# 4.0
# horn 46.wav
# 4.0
# horn 47.wav
# 4.0
# horn 48.wav
# 4.0
# horn 49.wav
# 4.0
# horn 50.wav
# ...

# %%
# Check if any audio files not within the desired duration
for filename in os.listdir(pathname):
  audio = AudioSegment.from_file(pathname + "/" + filename)
  if audio.duration_seconds != 4 and audio.duration_seconds < 3.999:
    print(filename)
    print(audio.duration_seconds)

# %%
# Obtain total duration of audio tracks
total_sec = 0
for filename in os.listdir(pathname):
  audio = AudioSegment.from_file(pathname + "/" + filename)
  total_sec += audio.duration_seconds

print(total_sec)
# Out:
# 883.9953574263036

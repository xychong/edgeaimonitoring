# %% [markdown]
# <a href="https://colab.research.google.com/github/xychong/edgeaimonitoring/blob/main/Preprocessing%5BMusic%5D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import librosa, librosa.display
import numpy as np
import os

# %%
pathname = "/content/drive/MyDrive/FYP Data/Music Playing"

# %%
# Display all filenames
sum = 0
for filename in os.listdir(pathname):
  sum += 1
  print(filename)
# Out:
# 113601-9-0-34.wav
# 14387-9-0-12.wav
# 138473-9-0-29.wav
# 138473-9-0-35.wav
# 14387-9-0-11.wav
# 14387-9-0-15.wav
# 113601-9-0-33.wav
# 131428-9-1-8.wav
# 113601-9-0-3.wav
# 138473-9-0-12.wav
# 131428-9-1-19.wav
# 124489-9-0-18.wav
# 131428-9-1-9.wav
# 113601-9-0-22.wav
# 131428-9-1-0.wav
# 131428-9-0-3.wav
# 124489-9-0-17.wav
# 124489-9-0-6.wav
# 131428-9-0-5.wav
# 108357-9-0-49.wav
# 124489-9-0-16.wav
# 124489-9-0-14.wav
# 108357-9-0-44.wav
# 124489-9-0-12.wav
# 115239-9-0-5.wav
# 115239-9-0-2.wav
# 115239-9-0-3.wav
# 115239-9-0-4.wav
# 108357-9-0-30.wav
# 115239-9-0-0.wav
# 115239-9-0-1.wav
# 109263-9-0-78.wav
# 108357-9-0-27.wav
# 109263-9-0-61.wav
# 109263-9-0-54.wav
# 109263-9-0-34.wav
# 109263-9-0-39.wav
# 107653-9-0-7.wav
# 108357-9-0-2.wav
# 107653-9-0-5.wav
# 107653-9-0-3.wav
# 107653-9-0-14.wav
# 107653-9-0-18.wav
# 108357-9-0-15.wav
# 107653-9-0-12.wav
# 39968-9-0-81.wav
# 42954-9-0-12.wav
# 39970-9-0-54.wav
# 39968-9-0-227.wav
# 39970-9-0-41.wav
# 149254-9-0-56.wav
# ...

# %%
# Check that all files are included
print (sum)
# Out:
# 224

# %%
n_fft = 2048
hop_length = 512
for filename in os.listdir(pathname):
  x,sr = librosa.load(pathname + "/" + filename, sr = 44100) # load audio file with sampling rate 44.1k Hz
  stft = librosa.stft(x, n_fft = n_fft, hop_length = hop_length)
  amplitudeindB = librosa.amplitude_to_db(np.abs(stft), ref=np.max)
  print (np.max(abs(amplitudeindB))) # gives us max dB value of audio for each audio file
# Out:
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# 80.0
# ...

# %% [markdown]
# This means that maximum audio level is at 80dB for all audio files in "Music Playing" dataset.

# %%
def displayTime(startFrame, endFrame):    
    print(' start time: ' + str(startFrame/sr) + ', end time: ' + str(endFrame/sr))

# %%
# Obtain non-silent intervals within each track
# Allows me to have a better idea of how to trim each track into the desired 4s duration
for filename in os.listdir(pathname):
  x,sr = librosa.load(pathname + "/" + filename, sr = 44100)
  nonmuteportions = librosa.effects.split(x) # default top_db = 60 dB
  for i in nonmuteportions:    
    print(filename)  
    displayTime(i[0],i[1])
# Out:
# 113601-9-0-34.wav
#  start time: 0.0, end time: 4.0
# 14387-9-0-12.wav
#  start time: 0.0, end time: 4.0
# 138473-9-0-29.wav
#  start time: 0.0, end time: 4.0
# 138473-9-0-35.wav
#  start time: 0.0, end time: 4.0
# 14387-9-0-11.wav
#  start time: 0.0, end time: 4.0
# 14387-9-0-15.wav
#  start time: 0.0, end time: 4.0
# 113601-9-0-33.wav
#  start time: 0.0, end time: 4.0
# 131428-9-1-8.wav
#  start time: 0.0, end time: 4.0
# 113601-9-0-3.wav
#  start time: 0.0, end time: 4.0
# 138473-9-0-12.wav
#  start time: 0.0, end time: 4.0
# 131428-9-1-19.wav
#  start time: 0.0, end time: 4.0
# 124489-9-0-18.wav
#  start time: 0.0, end time: 4.0
# 131428-9-1-9.wav
#  start time: 0.0, end time: 4.0
# 113601-9-0-22.wav
#  start time: 0.0, end time: 4.0
# 131428-9-1-0.wav
#  start time: 0.0, end time: 4.0
# 131428-9-0-3.wav
#  start time: 0.0, end time: 4.0
# 124489-9-0-17.wav
#  start time: 0.0, end time: 4.0
# 124489-9-0-6.wav
#  start time: 0.0, end time: 4.0
# 131428-9-0-5.wav
# ...

# %%
print(count)
# Out:
# 224

# %% [markdown]
# From data above, there are 2 audio tracks with silences at the beginning. Since the audio track is already at the desired audio length (4s), I will not be trimming the silences.
#
# There are 2 audio tracks longer than 4s. Hence, we need to segment these audio tracks into multiple segments of 4s each.

# %% [markdown]
# #### Trim audio tracks that are >4s into multiple tracks of 4s each

# %%
from pydub import AudioSegment

# %%
music1 = AudioSegment.from_wav(pathname + "/" + "469707__florianreichelt__a-man-playing-drums-in-marrakech-morocco.wav")

# %%
newfilename = "music1trimmed"

music1_1_4 = music1[:4000]
music1_1_4.export(pathname + "/" + newfilename + "1", format = "wav")

music1_2_4 = music1[4000:8000]
music1_2_4.export(pathname + "/" + newfilename + "2", format = "wav")

music1_3_4 = music1[8000:12000]
music1_3_4.export(pathname + "/" + newfilename + "3", format = "wav")

music1_4_4 = music1[12000:16000]
music1_4_4.export(pathname + "/" + newfilename + "4", format = "wav")

music1_5_4 = music1[16000:20000]
music1_5_4.export(pathname + "/" + newfilename + "5", format = "wav")

music1_6_4 = music1[20000:24000]
music1_6_4.export(pathname + "/" + newfilename + "6", format = "wav")

music1_empty_4 = music1[24000:25000]
music1_empty_4.export(pathname + "/" + newfilename + "empty", format = "wav")
# Out:
# <_io.BufferedRandom name='/content/drive/MyDrive/FYP Data/Music Playing/music1trimmedempty'>

# %%
music2 = AudioSegment.from_wav(pathname + "/" + "434606__johnlavine333__kora.wav")

# %%
newfilename = "music2trimmed"

music2_1_4 = music2[:4000]
music2_1_4.export(pathname + "/" + newfilename + "1", format = "wav")

music2_2_4 = music2[4000:8000]
music2_2_4.export(pathname + "/" + newfilename + "2", format = "wav")

music2_3_4 = music2[8000:12000]
music2_3_4.export(pathname + "/" + newfilename + "3", format = "wav")

music2_4_4 = music2[12000:16000]
music2_4_4.export(pathname + "/" + newfilename + "4", format = "wav")

music2_5_4 = music2[16000:20000]
music2_5_4.export(pathname + "/" + newfilename + "5", format = "wav")

music2_6_4 = music2[20000:24000]
music2_6_4.export(pathname + "/" + newfilename + "6", format = "wav")

music2_7_4 = music2[24000:28000]
music2_7_4.export(pathname + "/" + newfilename + "7", format = "wav")

music2_8_4 = music2[28000:32000]
music2_8_4.export(pathname + "/" + newfilename + "8", format = "wav")

music2_9_4 = music2[32000:36000]
music2_9_4.export(pathname + "/" + newfilename + "9", format = "wav")

music2_10_4 = music2[36000:40000]
music2_10_4.export(pathname + "/" + newfilename + "10", format = "wav")

music2_11_4 = music2[40000:44000]
music2_11_4.export(pathname + "/" + newfilename + "11", format = "wav")

music2_12_4 = music2[44000:48000]
music2_12_4.export(pathname + "/" + newfilename + "12", format = "wav")

music2_13_4 = music2[48000:52000]
music2_13_4.export(pathname + "/" + newfilename + "13", format = "wav")

music2_14_4 = music2[52000:56000]
music2_14_4.export(pathname + "/" + newfilename + "14", format = "wav")

music2_15_4 = music2[56000:60000]
music2_15_4.export(pathname + "/" + newfilename + "15", format = "wav")

music2_16_4 = music2[60000:64000]
music2_16_4.export(pathname + "/" + newfilename + "16", format = "wav")

music2_17_4 = music2[64000:68000]
music2_17_4.export(pathname + "/" + newfilename + "17", format = "wav")

music2_18_4 = music2[68000:72000]
music2_18_4.export(pathname + "/" + newfilename + "18", format = "wav")

music2_19_4 = music2[72000:76000]
music2_19_4.export(pathname + "/" + newfilename + "19", format = "wav")

music2_20_4 = music2[76000:80000]
music2_20_4.export(pathname + "/" + newfilename + "20", format = "wav")

music2_21_4 = music2[80000:84000]
music2_21_4.export(pathname + "/" + newfilename + "21", format = "wav")

music2_22_4 = music2[84000:88000]
music2_22_4.export(pathname + "/" + newfilename + "22", format = "wav")

music2_23_4 = music2[88000:92000]
music2_23_4.export(pathname + "/" + newfilename + "23", format = "wav")

music2_empty_4 = music2[92000:93000]
music2_empty_4.export(pathname + "/" + newfilename + "empty", format = "wav")
# Out:
# <_io.BufferedRandom name='/content/drive/MyDrive/FYP Data/Music Playing/music2trimmedempty'>

# %%
category = "Music"
count = 1;
for filename in os.listdir(pathname):
  os.rename(pathname + "/" + filename, pathname + "/" + category + " " + str(count))
  count += 1

# %%
from pydub.utils import mediainfo
import librosa

# %%
# actual sampling rate
for filename in os.listdir(pathname):
  info = mediainfo(pathname + "/" + filename)
  print (info['sample_rate'])
# Out:
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 48000
# 44100
# 44100
# 48000
# 44100
# 44100
# 44100
# 44100
# 44100
# 48000
# 44100
# 44100
# 48000
# 48000
# 48000
# 48000
# 48000
# 48000
# 44100
# 48000
# 44100
# 44100
# 44100
# 44100
# 48000
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 48000
# 44100
# 44100
# 44100
# 44100
# 44100
# 48000
# 44100
# 44100
# 48000
# 44100
# 44100
# 44100
# 44100
# 44100
# 48000
# 44100
# 44100
# 44100
# 48000
# ...

# %%
# sampling rate when loaded by librosa
for filename in os.listdir(pathname):
  y, s = librosa.load(pathname + "/" + filename, sr = 44100)
  print(s)
# Out:
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# 44100
# ...
